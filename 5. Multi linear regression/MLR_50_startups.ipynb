# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
startup = pd.read_csv("50_Startups1.csv")

# %%
startup.head(40)
# Out:
#            rd         ad         ms          St         Pr
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# 15  114523.61  122616.84  261776.23    New York  129917.04
# 16   78013.11  121597.55  264346.06  California  126992.93
# 17   94657.16  145077.58  282574.31    New York  125370.37
# 18   91749.16  114175.79  294919.57     Florida  124266.90
# 19   86419.70  153514.11       0.00    New York  122776.86
# 20   76253.86  113867.30  298664.47  California  118474.03
# 21   78389.47  153773.43  299737.29    New York  111313.02
# 22   73994.56  122782.75  303319.26     Florida  110352.25
# 23   67532.53  105751.03  304768.73     Florida  108733.99
# 24   77044.01   99281.34  140574.81    New York  108552.04
# 25   64664.71  139553.16  137962.62  California  107404.34
# 26   75328.87  144135.98  134050.07     Florida  105733.54
# 27   72107.60  127864.55  353183.81    New York  105008.31
# 28   66051.52  182645.56  118148.20     Florida  103282.38
# 29   65605.48  153032.06  107138.38    New York  101004.64
# 30   61994.48  115641.28   91131.24     Florida   99937.59
# 31   61136.38  152701.92   88218.23    New York   97483.56
# 32   63408.86  129219.61   46085.25  California   97427.84
# 33   55493.95  103057.49  214634.81     Florida   96778.92
# 34   46426.07  157693.92  210797.67  California   96712.80
# 35   46014.02   85047.44  205517.64    New York   96479.51
# 36   28663.76  127056.21  201126.82     Florida   90708.19
# 37   44069.95   51283.14  197029.42  California   89949.14
# 38   20229.59   65947.93  185265.10    New York   81229.06
# 39   38558.51   82982.09  174999.30  California   81005.76

# %%
startup.corr()
# Out:
#           rd        ad        ms        Pr
# rd  1.000000  0.241955  0.724248  0.972900
# ad  0.241955  1.000000 -0.032154  0.200717
# ms  0.724248 -0.032154  1.000000  0.747766
# Pr  0.972900  0.200717  0.747766  1.000000

# %%
import seaborn as sns
sns.pairplot(startup)

# %%
startup.columns
# Out:
# Index(['rd', 'ad', 'ms', 'St', 'Pr'], dtype='object')

# %%
import statsmodels.formula.api as smf

# %%
ml1 = smf.ols('ms~Pr+rd+ad',data=startup).fit()

# %%
ml1.params
# Out:
# Intercept    61688.169076
# Pr               2.064147
# rd               0.291961
# ad              -0.852098
# dtype: float64

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     22.47
# Date:                Fri, 25 Sep 2020   Prob (F-statistic):           4.17e-09
# Time:                        07:45:19   Log-Likelihood:                -633.59
# No. Observations:                  50   AIC:                             1275.
# Df Residuals:                      46   BIC:                             1283.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.169e+04   8.56e+04      0.720      0.475   -1.11e+05    2.34e+05
# Pr             2.0641      1.247      1.655      0.105      -0.446       4.575
# rd             0.2920      1.106      0.264      0.793      -1.934       2.518
# ad            -0.8521      0.428     -1.993      0.052      -1.713       0.009
# ==============================================================================
# Omnibus:                        3.384   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.184   Jarque-Bera (JB):                3.049
# Skew:                           0.070   Prob(JB):                        0.218
# Kurtosis:                       4.202   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ml_v=smf.ols('ms~rd',data = startup).fit()

# %%
ml_v.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     52.95
# Date:                Fri, 25 Sep 2020   Prob (F-statistic):           2.77e-09
# Time:                        07:48:52   Log-Likelihood:                -637.56
# No. Observations:                  50   AIC:                             1279.
# Df Residuals:                      48   BIC:                             1283.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.878e+04    2.3e+04      2.995      0.004    2.26e+04    1.15e+05
# rd             1.9295      0.265      7.277      0.000       1.396       2.463
# ==============================================================================
# Omnibus:                        3.201   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.202   Jarque-Bera (JB):                2.221
# Skew:                          -0.342   Prob(JB):                        0.329
# Kurtosis:                       3.774   Cond. No.                     1.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ml_w=smf.ols('ms~ad',data = startup).fit()

# %%
ml_w.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                   0.04968
# Date:                Fri, 25 Sep 2020   Prob (F-statistic):              0.825
# Time:                        07:49:42   Log-Likelihood:                -656.12
# No. Observations:                  50   AIC:                             1316.
# Df Residuals:                      48   BIC:                             1320.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.281e+05   7.84e+04      2.910      0.005    7.05e+04    3.86e+05
# ad            -0.1403      0.630     -0.223      0.825      -1.406       1.126
# ==============================================================================
# Omnibus:                        1.374   Durbin-Watson:                   0.842
# Prob(Omnibus):                  0.503   Jarque-Bera (JB):                1.041
# Skew:                          -0.031   Prob(JB):                        0.594
# Kurtosis:                       2.296   Cond. No.                     5.59e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ml_wv=smf.ols('ms~Pr+rd',data = startup).fit()

# %%
ml_wv.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     29.83
# Date:                Fri, 25 Sep 2020   Prob (F-statistic):           4.33e-09
# Time:                        07:51:22   Log-Likelihood:                -635.66
# No. Observations:                  50   AIC:                             1277.
# Df Residuals:                      47   BIC:                             1283.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5.127e+04   6.62e+04     -0.775      0.442   -1.84e+05    8.19e+04
# Pr             2.4484      1.271      1.927      0.060      -0.108       5.004
# rd            -0.1621      1.116     -0.145      0.885      -2.406       2.082
# ==============================================================================
# Omnibus:                        3.741   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                3.178
# Skew:                          -0.248   Prob(JB):                        0.204
# Kurtosis:                       4.131   Cond. No.                     8.25e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(ml1)

# %%
startup_new=startup.drop(startup.index[[47,48]],axis=0)
startup_new
# Out:
#            rd         ad         ms          St         Pr
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# 15  114523.61  122616.84  261776.23    New York  129917.04
# 16   78013.11  121597.55  264346.06  California  126992.93
# 17   94657.16  145077.58  282574.31    New York  125370.37
# 18   91749.16  114175.79  294919.57     Florida  124266.90
# 19   86419.70  153514.11       0.00    New York  122776.86
# 20   76253.86  113867.30  298664.47  California  118474.03
# 21   78389.47  153773.43  299737.29    New York  111313.02
# 22   73994.56  122782.75  303319.26     Florida  110352.25
# 23   67532.53  105751.03  304768.73     Florida  108733.99
# 24   77044.01   99281.34  140574.81    New York  108552.04
# 25   64664.71  139553.16  137962.62  California  107404.34
# 26   75328.87  144135.98  134050.07     Florida  105733.54
# 27   72107.60  127864.55  353183.81    New York  105008.31
# 28   66051.52  182645.56  118148.20     Florida  103282.38
# 29   65605.48  153032.06  107138.38    New York  101004.64
# 30   61994.48  115641.28   91131.24     Florida   99937.59
# 31   61136.38  152701.92   88218.23    New York   97483.56
# 32   63408.86  129219.61   46085.25  California   97427.84
# 33   55493.95  103057.49  214634.81     Florida   96778.92
# 34   46426.07  157693.92  210797.67  California   96712.80
# 35   46014.02   85047.44  205517.64    New York   96479.51
# 36   28663.76  127056.21  201126.82     Florida   90708.19
# 37   44069.95   51283.14  197029.42  California   89949.14
# 38   20229.59   65947.93  185265.10    New York   81229.06
# 39   38558.51   82982.09  174999.30  California   81005.76
# 40   28754.33  118546.05  172795.67  California   78239.91
# 41   27892.92   84710.77  164470.71     Florida   77798.83
# 42   23640.93   96189.63  148001.11  California   71498.49
# 43   15505.73  127382.30   35534.17    New York   69758.98
# 44   22177.74  154806.14   28334.72  California   65200.33
# 45    1000.23  124153.04    1903.93    New York   64926.08
# 46    1315.46  115816.21  297114.46     Florida   49490.75
# 49       0.00  116983.80   45173.06  California   14681.40

# %%
ml1_new = smf.ols('ms~Pr+rd+ad',data=startup).fit()

# %%
ml1_new.params
# Out:
# Intercept    61688.169076
# Pr               2.064147
# rd               0.291961
# ad              -0.852098
# dtype: float64

# %%
ml1_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     22.47
# Date:                Fri, 25 Sep 2020   Prob (F-statistic):           4.17e-09
# Time:                        07:55:42   Log-Likelihood:                -633.59
# No. Observations:                  50   AIC:                             1275.
# Df Residuals:                      46   BIC:                             1283.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.169e+04   8.56e+04      0.720      0.475   -1.11e+05    2.34e+05
# Pr             2.0641      1.247      1.655      0.105      -0.446       4.575
# rd             0.2920      1.106      0.264      0.793      -1.934       2.518
# ad            -0.8521      0.428     -1.993      0.052      -1.713       0.009
# ==============================================================================
# Omnibus:                        3.384   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.184   Jarque-Bera (JB):                3.049
# Skew:                           0.070   Prob(JB):                        0.218
# Kurtosis:                       4.202   Cond. No.                     1.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
startup_pred = ml1_new.predict(startup_new[['ms','Pr','rd','ad']])
startup_pred
# Out:
# 0     390170.132794
# 1     376058.929127
# 2     414657.373312
# 3     380255.927768
# 4     368339.652382
# 5     339192.000741
# 6     297822.674663
# 7     297220.622287
# 8     284346.321433
# 9     314218.495728
# 10    298823.055646
# 11    310638.541071
# 12    272856.685146
# 13    250321.470351
# 14    237024.621705
# 15    258810.979343
# 16    242984.069273
# 17    224487.001296
# 18    247691.602050
# 19    209539.846645
# 20    231473.101935
# 21    183311.311011
# 22    206452.088446
# 23    215737.791057
# 24    223652.011982
# 25    183353.183286
# 26    179112.916563
# 27    190540.299457
# 28    138530.804627
# 29    158932.587005
# 30    187536.369626
# 31    150641.067014
# 32    171198.754553
# 33    189841.127129
# 34    140501.591923
# 35    201801.653336
# 36    149027.613155
# 37    216524.902282
# 38    179069.075975
# 39    169444.715338
# 40    130569.179413
# 41    158238.196136
# 42    134210.838580
# 43    101665.863800
# 44     70836.312488
# 45     90206.648171
# 46     65541.684278
# 49     -7688.903464
# dtype: float64

# %%
sm.graphics.plot_partregress_grid(ml1_new)

# %%
final_ml= smf.ols('ms~Pr+rd+ad',data = startup_new).fit()
final_ml.params
final_ml.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ms   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.525
# Method:                 Least Squares   F-statistic:                     18.33
# Date:                Wed, 30 Sep 2020   Prob (F-statistic):           7.31e-08
# Time:                        15:36:24   Log-Likelihood:                -608.17
# No. Observations:                  48   AIC:                             1224.
# Df Residuals:                      44   BIC:                             1232.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.23e+05   9.65e+04      1.274      0.209   -7.16e+04    3.17e+05
# Pr             1.5078      1.309      1.152      0.256      -1.130       4.146
# rd             0.6773      1.142      0.593      0.556      -1.624       2.978
# ad            -1.0499      0.462     -2.273      0.028      -1.981      -0.119
# ==============================================================================
# Omnibus:                        2.565   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.277   Jarque-Bera (JB):                1.847
# Skew:                           0.014   Prob(JB):                        0.397
# Kurtosis:                       3.960   Cond. No.                     1.59e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sm.graphics.plot_partregress_grid(final_ml)

# %%
plt.scatter(startup_new.Pr,startup_pred,c="r");plt.xlabel("observed_values");plt.ylabel("fitted_values")
# Out:
# Text(0, 0.5, 'fitted_values')

# %%
plt.scatter(startup_pred,final_ml.resid_pearson,c="r"),plt.axhline(y=0,color='blue');plt.xlabel("fitted_values");plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')

# %%
plt.hist(final_ml.resid_pearson)
# Out:
# (array([ 2.,  1.,  3.,  9., 12., 10.,  7.,  2.,  1.,  1.]),
#  array([-2.5548901 , -2.0254935 , -1.4960969 , -0.9667003 , -0.4373037 ,
#          0.0920929 ,  0.6214895 ,  1.15088609,  1.68028269,  2.20967929,
#          2.73907589]),
#  <a list of 10 Patch objects>)

# %%
import pylab          
import scipy.stats as st

# %%
st.probplot(final_ml.resid_pearson, dist="norm", plot=pylab)
# Out:
# ((array([-2.18794508, -1.81466696, -1.5940389 , -1.43152593, -1.29991017,
#          -1.18761792, -1.08858668, -0.99921942, -0.91719469, -0.84091983,
#          -0.76924975, -0.7013297 , -0.63650166, -0.57424545, -0.51414026,
#          -0.45583845, -0.39904728, -0.34351563, -0.28902427, -0.23537844,
#          -0.18240202, -0.12993297, -0.07781945, -0.02591656,  0.02591656,
#           0.07781945,  0.12993297,  0.18240202,  0.23537844,  0.28902427,
#           0.34351563,  0.39904728,  0.45583845,  0.51414026,  0.57424545,
#           0.63650166,  0.7013297 ,  0.76924975,  0.84091983,  0.91719469,
#           0.99921942,  1.08858668,  1.18761792,  1.29991017,  1.43152593,
#           1.5940389 ,  1.81466696,  2.18794508]),
#   array([-2.5548901 , -2.08028084, -1.62980073, -1.28203518, -1.16906161,
#          -1.11023979, -0.86264612, -0.8336382 , -0.78109242, -0.77779815,
#          -0.64515419, -0.59721102, -0.5648109 , -0.54989283, -0.46710387,
#          -0.20519285, -0.16801752, -0.16436805, -0.1130362 , -0.09533959,
#          -0.07338307, -0.07142321, -0.05949138, -0.05758208, -0.01024769,
#           0.02760008,  0.08893192,  0.14018152,  0.20359283,  0.20819937,
#           0.23215166,  0.28487406,  0.30765182,  0.38077637,  0.4184773 ,
#           0.45839162,  0.52637942,  0.68881338,  0.73116359,  0.80807935,
#           0.94691935,  1.00189402,  1.03412579,  1.12763454,  1.15371399,
#           1.45879426,  1.95631545,  2.73907589])),
#  (0.9796259090159595, -2.204958303495399e-15, 0.9855324299875128))

# %%
plt.scatter(startup_pred,final_ml.resid_pearson,c="r"),plt.axhline(y=0,color='blue');plt.xlabel("fitted_values");plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')

# %%
from sklearn.model_selection import train_test_split
startup_train,startup_test  = train_test_split(startup_new,test_size = 0.2)
startup_train
startup_test
# Out:
#            rd         ad         ms          St         Pr
# 16   78013.11  121597.55  264346.06  California  126992.93
# 40   28754.33  118546.05  172795.67  California   78239.91
# 15  114523.61  122616.84  261776.23    New York  129917.04
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 29   65605.48  153032.06  107138.38    New York  101004.64
# 42   23640.93   96189.63  148001.11  California   71498.49
# 19   86419.70  153514.11       0.00    New York  122776.86
# 43   15505.73  127382.30   35534.17    New York   69758.98

# %%
model_train = smf.ols("ms~Pr+rd+ad",data=startup_train).fit()

# %%
train_pred = model_train.predict(startup_train)

# %%
train_resid  = train_pred - startup_train.Pr

# %%
train_resid
# Out:
# 3     168743.811702
# 22    103376.051304
# 34     55390.835920
# 24    123674.884820
# 10    140272.266651
# 36     68918.443474
# 30     99302.552688
# 13    110608.760436
# 5     168863.609901
# 8     121107.490782
# 35    114599.202895
# 32     88110.815075
# 11    154388.369426
# 39    107141.536867
# 33    105057.932575
# 25     83630.196741
# 12    120726.595747
# 37    139044.078009
# 14    107872.068052
# 21     80678.760760
# 26     85073.341860
# 23    113306.268425
# 45     47832.567018
# 4     184328.607209
# 6     131238.110521
# 20    114589.503920
# 31     67668.403530
# 27     96424.440831
# 41     98910.831921
# 28     47712.948409
# 46     49715.457796
# 9     154599.004032
# 49     36511.792477
# 18    124613.155246
# 17    101234.121504
# 38    111284.615239
# 7     130154.260313
# 44     34234.715926
# dtype: float64

# %%
train_rmse = np.sqrt(np.mean(train_resid*train_resid))
train_rmse
# Out:
# 111229.33706605258

# %%
test_pred = model_train.predict(startup_test)
test_pred
# Out:
# 16    239022.630651
# 40    150045.525556
# 15    261770.278966
# 0     360490.661124
# 1     346520.334245
# 2     381742.367387
# 29    171979.783911
# 42    156625.188191
# 19    211798.341004
# 43    124370.702150
# dtype: float64

# %%
test_resid  = test_pred - startup_test.Pr

# %%
test_rmse = np.sqrt(np.mean(test_resid*test_resid))
test_rmse
# Out:
# 121197.55594294592
